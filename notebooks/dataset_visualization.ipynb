# %% [markdown]
# # LoL dataset visualization

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
from IPython.display import display

from importlib import reload
import neuralol
_ = reload(neuralol)

# %% [markdown]
# ### Players game stats

# %%
players_game_stats = pd.read_csv('../data/raw/game_players_stats.csv')
print(f"{players_game_stats.shape[0]} rows and {players_game_stats.shape[1]} columns")
display(players_game_stats.head(10))
# Out:
# 374554 rows and 28 columns
#    game_id  player_id player_name  team_id               team_name  \
# 0       15          0      shanji        0    Legend Esport Gaming
# 1       15          1       Demon        1  Bilibili Gaming Junior
# 2       15          2     yanxuan        0    Legend Esport Gaming
# 3       15          3        Viod        0    Legend Esport Gaming
# 4       15          4     HanXuan        1  Bilibili Gaming Junior
# 5       15          5         Yui        1  Bilibili Gaming Junior
# 6       15          6   Chieftain        1  Bilibili Gaming Junior
# 7       15          7       Virus        1  Bilibili Gaming Junior
# 8       15          8    Assassin        0    Legend Esport Gaming
# 9       15          9      CatJug        0    Legend Esport Gaming
#
#   team_acronym     role    win  game_length champion_name  ...  \
# 0          LEG      Top  False         1415        Irelia  ...
# 1         BLGJ      Top   True         1415      Vladimir  ...
# ...

# %% [markdown]
# ### Game metadata

# %%
players_game_stats = pd.read_csv('../data/raw/game_metadata.csv')
print(f"{players_game_stats.shape[0]} rows and {players_game_stats.shape[1]} columns")
display(players_game_stats.head(10))
# Out:
# 37459 rows and 9 columns
#    game_id                        date  match_id  tournament_id  \
# 0        0  2019-09-15 10:17:30.487000         0              0
# 1        1  2019-09-15 11:18:01.085000         0              0
# 2        2  2019-09-15 12:11:33.489000         0              0
# 3        3  2019-09-15 13:03:19.662000         0              0
# 4        4  2019-09-16 04:32:28.724000         1              1
# 5        5  2019-09-16 05:29:41.680000         1              1
# 6        6  2019-09-16 06:45:07.195000         1              1
# 7        7  2019-09-16 07:45:59.496000         1              1
# 8        8  2019-09-15 15:08:08.817000         2              2
# 9        9  2019-09-15 16:03:21.799000         2              2
#
#    tournament_name  series_id      series_name  league_id league_name
# 0         Playoffs          0  VCS Summer 2019          0         VCS
# 1         Playoffs          0  VCS Summer 2019          0         VCS
# ...

# %% [markdown]
# ### Game events

# %%
players_game_stats = pd.read_csv('../data/raw/game_events.csv')
print(f"{players_game_stats.shape[0]} rows and {players_game_stats.shape[1]} columns")
display(players_game_stats.head(10))
# Out:
# 1884740 rows and 8 columns
#    id  game_id  timestamp   event_type  killer_id  killed_id  \
# 0   0        0        229  player_kill       21.0       29.0
# 1   1        0        289  player_kill       21.0       29.0
# 2   2        0        499  player_kill       25.0       21.0
# 3   3        0        504  player_kill       22.0       23.0
# 4   4        0        535  player_kill       28.0       24.0
# 5   5        0        698  player_kill       28.0       24.0
# 6   6        0        700  player_kill       23.0       26.0
# 7   7        0        705  player_kill       27.0       25.0
# 8   8        0        819  player_kill       28.0       24.0
# 9   9        0        823  player_kill       22.0       28.0
#
#   assisting_player_ids drake_type
# 0                 [23]        NaN
# 1                 [23]        NaN
# 2             [29, 22]        NaN
# 3             [29, 25]        NaN
# 4                 [27]        NaN
# 5     [21, 23, 30, 27]        NaN
# ...
